# %% [markdown]
# # Environment & Dependency Check
#
# This notebook is based on [episode 1](https://carpentries-lab.github.io/deep-learning-intro/1-introduction.html) and verifies that all required packages are installed and meet the minimum version requirements for the [Introduction to Deep Learning](https://carpentries-lab.github.io/deep-learning-intro/index.html) Carpentries course.
#
# ---
#
# ### Platform
#
# Tested on **UCL's Unified AI Platform** (5 CPUs, 64 GB RAM).
# It should also run in any standard Python environment with the required packages installed.
#
# > **Need help?** Contact the ARC Collaborations team at [ARC.Collaborations@ucl.ac.uk](mailto:ARC.Collaborations@ucl.ac.uk) for support with AI platforms, GPUs, or Carpentries training.
#
# ---
#
# ### How to run
#
# | Shortcut | Action |
# |---|---|
# | `Shift + Enter` | Run current cell, move to next |
# | `Alt + Enter` | Run current cell, insert new cell below |
# | `Ctrl + Shift + F9` | Restart kernel and run all cells |
#
# Run all cells top-to-bottom. The final cell will tell you whether your environment is ready.

# %% [markdown]
# ## 1 Python & System Information
#
# Record the Python version and platform so results are reproducible and easier to debug.

# %%
import sys
import platform
from datetime import datetime

print(f"Date/Time : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Python    : {sys.version}")
print(f"Platform  : {platform.platform()}")
print(f"Machine   : {platform.machine()}")
# Out:
# Date/Time : 2026-05-28 21:01:19
# Python    : 3.11.10 | packaged by conda-forge | (main, Sep 30 2024, 18:08:57) [GCC 13.3.0]
# Platform  : Linux-5.14.0-570.30.1.el9_6.x86_64-x86_64-with-glibc2.35
# Machine   : x86_64

# %% [markdown]
# ## 2 Import Packages
#
# Import all required packages. If any import fails here, install the missing package and restart the kernel before continuing.
#
# > Versions from the course
# > For Keras and Tensorflow, the minimum version is 2.12.0 - For sklearn, the minimum version is 1.2.2
# > Page: https://carpentries-lab.github.io/deep-learning-intro/index.html
# > Source: https://github.com/carpentries-lab/deep-learning-intro/blob/main/learners/setup.md#check-your-setup

# %%
import tensorflow
import tensorboard
import sklearn
import seaborn
import keras_tuner
import pydot


print("tensorflow:", tensorflow.__version__)
print("tensorboard:", tensorboard.__version__)
print("sklearn:", sklearn.__version__)
print("seaborn:", seaborn.__version__)
print("keras_tuner:", keras_tuner.__version__)
print("pydot:", pydot.__version__)


print("All packages imported successfully.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780002079.662674 1405306 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow: 2.21.0
# tensorboard: 2.20.0
# sklearn: 1.8.0
# seaborn: 0.13.2
# keras_tuner: 1.4.8
# pydot: 4.0.1
# All packages imported successfully.

# %% [markdown]
# ## 3. Install / Upgrade (if needed)
#
# Only run this cell if the version check above reported a `FAIL`.
# After running it, **restart the kernel** and re-run from Cell 1.

# %%
# Uncomment and run only if you need to install packages
# Then restart the kernel and re-run all cells.

# %pip install --upgrade \
#     "tensorflow>=2.12.0" \
#     "scikit-learn>=1.2.2" \
#     "seaborn>=0.12.0" \
#     "keras-tuner>=1.3.0" \
#     "pydot>=1.4.0"

# %% [markdown]
# ---
#
# ## References
#
# - Course homepage: [Introduction to Deep Learning (Carpentries)](https://carpentries-lab.github.io/deep-learning-intro/index.html)
# - Setup instructions: [learners/setup.md](https://github.com/carpentries-lab/deep-learning-intro/blob/main/learners/setup.md#check-your-setup)
# - [scikit-learn on PyPI](https://pypi.org/project/scikit-learn/)
# - [TensorFlow on PyPI](https://pypi.org/project/tensorflow/#history)
# - [Keras metrics API](https://keras.io/api/metrics/)
# - [keras-tuner on PyPI](https://pypi.org/project/keras-tuner/)
